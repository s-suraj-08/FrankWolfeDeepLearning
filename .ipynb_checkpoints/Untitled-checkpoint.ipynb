# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# %load_ext autoreload
# %autoreload 2
from data import get_data_loaders
from models import get_model
from losses import get_loss
from runs import whichRun
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ROOT = r"E:\Suraj\University\Saarland\STUDIES\3d sem subjects\z_opt_ml\coderepo\datasets\cifar10\cifar-10-python\cifar10"

# %%
class setGlobals():
    def set(self,DATASET,ROOT,BATCH_SIZE,MODEL_TYPE,OPT,LOSS,SMOOTHING,EPOCHS,LEARNING_RATE,DECAY_FACTOR
                ,TYPE,REGPARAM,EARLYSTOP,AUGMENT,DROPOUT,DROP_PERCENT,MOMENTUM, PARAMS_TO_UPDATE):
        self.DATASET = DATASET
        self.ROOT = ROOT
        self.BATCH_SIZE = BATCH_SIZE

        self.MODEL_TYPE = MODEL_TYPE
        self.OPT = OPT
        self.LOSS = LOSS
        self.SMOOTHING = SMOOTHING
        self.EPOCHS = EPOCHS
        self.LEARNING_RATE = LEARNING_RATE
        self.DECAY_FACTOR = DECAY_FACTOR
        
        self.TYPE = TYPE
        self.REGPARAM = REGPARAM
        self.EARLYSTOP = EARLYSTOP
        self.AUGMENT = AUGMENT
        self.DROPOUT = DROPOUT
        self.DROP_PERCENT = DROP_PERCENT
        self.MOMENTUM = MOMENTUM
        
        self.PARAMS_TO_UPDATE = PARAMS_TO_UPDATE

# %%
class loadVals():
    def g_data(self,args):
      #get the dataset you want mnist/cifar10
        loader_train, loader_val, loader_test = get_data_loaders(dataset=args.DATASET,               
                                                                root = args.ROOT,
                                                                batch_size = args.BATCH_SIZE,        
                                                                augment = args.AUGMENT)              
        return loader_train, loader_val, loader_test
    
    def g_model(self,args,device):
        #get the model, types are 
        model,nparams,args.PARAMS_TO_UPDATE = get_model(args.DATASET,                          
                                                        m_type = args.MODEL_TYPE,                
                                                        device = device,                            
                                                        dropout = args.DROPOUT,                  
                                                        percent_dropout = args.DROP_PERCENT,
                                                        opt = args.OPT)
        return model,nparams
    
    def g_loss(self,args,device):
        loss = get_loss(ls = args.LOSS, 
                        regparam = args.REGPARAM,
                        device = device)
        return loss
    
    def g_optim(self,args,model):
        if glob.TYPE == "L2":
            regparam = args.REGPARAM
        else:
            regparam = 0
        optim = get_optimizer(opt = args.OPT,                                
                     eta = args.LEARNING_RATE,                       
                     regparam = regparam,
                     momentum = args.MOMENTUM,
                     parameters = args.PARAMS_TO_UPDATE)
        return optim

# %%
def graph_acc_loss(train_acc, val_acc, train_loss, val_loss, args):
    fig,axis = plt.subplots(1,2)
    fig.set_size_inches(12,6)
    
    axis[0].plot(train_acc, label = "train")
    axis[0].plot(val_acc, label = "validation")
    axis[0].set_ylabel("Accuracy")
    axis[0].set_xlabel("Epochs")
    axis[0].set_title("Accuracy vs Epcohs")
    
    axis[1].plot(train_loss, label = "train")
    axis[1].plot(val_loss, label = "validation")
    axis[1].set_ylabel("Loss")
    axis[1].set_xlabel("Epochs")
    axis[1].set_title("Loss vs Epcohs")
    
    plt.legend()
    plt.show()

# %%
glob = setGlobals()
l_vals = loadVals()

# %%
run = whichRun(glob,l_vals,device,
               root=ROOT)

# %%
##### TEST THE CLAIM OF BETTER GENERALISATION WITH HIGHER INITIAL LEARNING RATE #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = run.run('1_1')  #using sgd with lr = 1e-1
train_acc2, train_loss2, val_acc2, val_loss2, test_acc2 = run.run('1_2')  #using sgd with lr = 1e-3
# Out:
# Not using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# L2 regularization: 	 0
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Validataion accuracy is: 49.38 %
# Validataion accuracy is: 30.88 %
# decay_factor: 0.85
# Validataion accuracy is: 58.5 %
# Validataion accuracy is: 57.3 %
# Validataion accuracy is: 60.82 %
# decay_factor: 0.85
# Validataion accuracy is: 43.14 %
# Validataion accuracy is: 53.96 %
# Validataion accuracy is: 58.44 %
# decay_factor: 0.85
# Validataion accuracy is: 67.12 %
# Validataion accuracy is: 61.62 %
# Validataion accuracy is: 63.4 %
# decay_factor: 0.85
# Validataion accuracy is: 64.98 %
# Validataion accuracy is: 69.26 %
# Validataion accuracy is: 69.5 %
# decay_factor: 0.85
# Validataion accuracy is: 29.74 %
# Validataion accuracy is: 65.88 %
# Validataion accuracy is: 64.8 %
# decay_factor: 0.85
# Validataion accuracy is: 70.6 %
# Validataion accuracy is: 70.5 %
# Validataion accuracy is: 68.82 %
# decay_factor: 0.85
# Validataion accuracy is: 70.02 %
# Validataion accuracy is: 69.8 %
# Validataion accuracy is: 70.82 %
# decay_factor: 0.85
# Validataion accuracy is: 71.46 %
# Validataion accuracy is: 71.7 %
# Validataion accuracy is: 71.4 %
# decay_factor: 0.85
# Validataion accuracy is: 71.62 %
# Validataion accuracy is: 71.68 %
# Validataion accuracy is: 71.5 %
# decay_factor: 0.85
# Validataion accuracy is: 71.64 %
# Validataion accuracy is: 71.82 %
# Validataion accuracy is: 71.8 %
# decay_factor: 0.85
# Validataion accuracy is: 71.78 %
# Validataion accuracy is: 71.9 %
# Validataion accuracy is: 71.82 %
# decay_factor: 0.85
# Validataion accuracy is: 71.72 %
# Validataion accuracy is: 71.76 %
# Validataion accuracy is: 71.88 %
# decay_factor: 0.85
# Validataion accuracy is: 71.84 %
# Validataion accuracy is: 71.84 %
# Validataion accuracy is: 71.74 %
# decay_factor: 0.85
# Validataion accuracy is: 71.76 %
# Validataion accuracy is: 71.92 %
# Validataion accuracy is: 71.8 %
# decay_factor: 0.85
# Validataion accuracy is: 71.9 %
# Validataion accuracy is: 71.8 %
# Validataion accuracy is: 71.98 %
# decay_factor: 0.85
# Validataion accuracy is: 71.86 %
# Validataion accuracy is: 71.88 %
# Validataion accuracy is: 71.9 %
# Testing Accuracy of the network on the 10000 test images: 69.75 %
# Not using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# L2 regularization: 	 0
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Validataion accuracy is: 21.18 %
# Validataion accuracy is: 27.12 %
# decay_factor: 0.85
# Validataion accuracy is: 30.46 %
# Validataion accuracy is: 34.18 %
# Validataion accuracy is: 36.4 %
# decay_factor: 0.85
# Validataion accuracy is: 36.04 %
# Validataion accuracy is: 39.12 %
# Validataion accuracy is: 41.46 %
# decay_factor: 0.85
# Validataion accuracy is: 41.78 %
# Validataion accuracy is: 42.92 %
# Validataion accuracy is: 43.9 %
# decay_factor: 0.85
# Validataion accuracy is: 44.78 %
# Validataion accuracy is: 44.9 %
# Validataion accuracy is: 45.68 %
# decay_factor: 0.85
# Validataion accuracy is: 46.14 %
# Validataion accuracy is: 46.6 %
# Validataion accuracy is: 47.32 %
# decay_factor: 0.85
# Validataion accuracy is: 47.66 %
# Validataion accuracy is: 47.6 %
# Validataion accuracy is: 48.26 %
# decay_factor: 0.85
# Validataion accuracy is: 48.28 %
# Validataion accuracy is: 48.58 %
# Validataion accuracy is: 48.64 %
# decay_factor: 0.85
# Validataion accuracy is: 48.9 %
# Validataion accuracy is: 48.94 %
# Validataion accuracy is: 49.3 %
# decay_factor: 0.85
# Validataion accuracy is: 49.1 %
# Validataion accuracy is: 49.92 %
# Validataion accuracy is: 50.32 %
# decay_factor: 0.85
# Validataion accuracy is: 50.16 %
# Validataion accuracy is: 50.54 %
# Validataion accuracy is: 50.5 %
# decay_factor: 0.85
# Validataion accuracy is: 50.64 %
# Validataion accuracy is: 50.8 %
# Validataion accuracy is: 51.26 %
# decay_factor: 0.85
# Validataion accuracy is: 51.04 %
# Validataion accuracy is: 51.24 %
# Validataion accuracy is: 51.38 %
# decay_factor: 0.85
# Validataion accuracy is: 51.72 %
# Validataion accuracy is: 51.78 %
# Validataion accuracy is: 51.84 %
# decay_factor: 0.85
# Validataion accuracy is: 51.82 %
# Validataion accuracy is: 51.86 %
# Validataion accuracy is: 51.94 %
# decay_factor: 0.85
# Validataion accuracy is: 52.1 %
# Validataion accuracy is: 52.16 %
# Validataion accuracy is: 52.18 %
# decay_factor: 0.85
# Validataion accuracy is: 52.36 %
# Validataion accuracy is: 52.3 %
# Validataion accuracy is: 52.46 %
# Testing Accuracy of the network on the 10000 test images: 51.52 %

# %%
graph_acc_loss(train_acc1, val_acc1, train_loss1, val_loss1, glob)

# %%
graph_acc_loss(train_acc2, val_acc2, train_loss2, val_loss2, glob)

# %%
##### TEST THE CLAIM OF BETTER GENERALISATION WITH HIGHER INITIAL LEARNING RATE #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = run.run('2_1')  #using dfw with lr = 1e-1
train_acc2, train_loss2, val_acc2, val_loss2, test_acc2 = run.run('2_2')  #using dfw with lr = 1e-3
# Out:
# Not using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# L2 regularization: 	 0
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Validataion accuracy is: 55.3 %
# Validataion accuracy is: 64.0 %
# Validataion accuracy is: 68.98 %
# Validataion accuracy is: 70.44 %
# Validataion accuracy is: 71.76 %
# Validataion accuracy is: 71.72 %
# Validataion accuracy is: 73.12 %
# Validataion accuracy is: 73.3 %
# Validataion accuracy is: 73.38 %
# Validataion accuracy is: 73.58 %
# Validataion accuracy is: 72.78 %
# Validataion accuracy is: 73.12 %
# Validataion accuracy is: 73.92 %
# Validataion accuracy is: 73.82 %
# Validataion accuracy is: 73.78 %
# Validataion accuracy is: 73.24 %
# Validataion accuracy is: 74.1 %
# Validataion accuracy is: 73.94 %
# Validataion accuracy is: 73.74 %
# Validataion accuracy is: 73.52 %
# Validataion accuracy is: 73.8 %
# Validataion accuracy is: 73.3 %
# Validataion accuracy is: 73.56 %
# Validataion accuracy is: 73.52 %
# Validataion accuracy is: 73.58 %
# Validataion accuracy is: 73.44 %
# Validataion accuracy is: 73.12 %
# Validataion accuracy is: 73.28 %
# Validataion accuracy is: 73.16 %
# Validataion accuracy is: 72.82 %
# Validataion accuracy is: 73.22 %
# Validataion accuracy is: 72.88 %
# Validataion accuracy is: 72.72 %
# Validataion accuracy is: 72.6 %
# Validataion accuracy is: 72.72 %
# Validataion accuracy is: 72.68 %
# Validataion accuracy is: 72.72 %
# Validataion accuracy is: 73.02 %
# Validataion accuracy is: 72.56 %
# Validataion accuracy is: 72.72 %
# Validataion accuracy is: 72.32 %
# Validataion accuracy is: 72.46 %
# Validataion accuracy is: 72.4 %
# Validataion accuracy is: 72.16 %
# Validataion accuracy is: 72.38 %
# Validataion accuracy is: 72.1 %
# Validataion accuracy is: 72.2 %
# Validataion accuracy is: 72.6 %
# Validataion accuracy is: 72.32 %
# Validataion accuracy is: 72.42 %
# Testing Accuracy of the network on the 10000 test images: 70.37 %
# Not using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# L2 regularization: 	 0
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Validataion accuracy is: 15.16 %
# Validataion accuracy is: 25.08 %
# Validataion accuracy is: 29.04 %
# Validataion accuracy is: 32.92 %
# Validataion accuracy is: 34.78 %
# Validataion accuracy is: 37.68 %
# Validataion accuracy is: 39.48 %
# Validataion accuracy is: 40.6 %
# Validataion accuracy is: 41.46 %
# Validataion accuracy is: 43.74 %
# Validataion accuracy is: 44.8 %
# Validataion accuracy is: 44.14 %
# Validataion accuracy is: 46.68 %
# Validataion accuracy is: 44.12 %
# Validataion accuracy is: 48.1 %
# Validataion accuracy is: 50.1 %
# Validataion accuracy is: 48.24 %
# Validataion accuracy is: 51.08 %
# Validataion accuracy is: 50.66 %
# Validataion accuracy is: 47.86 %
# Validataion accuracy is: 53.9 %
# Validataion accuracy is: 53.1 %
# Validataion accuracy is: 53.14 %
# Validataion accuracy is: 53.02 %
# Validataion accuracy is: 53.76 %
# Validataion accuracy is: 54.78 %
# Validataion accuracy is: 54.84 %
# Validataion accuracy is: 55.22 %
# Validataion accuracy is: 55.44 %
# Validataion accuracy is: 56.98 %
# Validataion accuracy is: 57.36 %
# Validataion accuracy is: 56.78 %
# Validataion accuracy is: 59.04 %
# Validataion accuracy is: 59.3 %
# Validataion accuracy is: 58.6 %
# Validataion accuracy is: 58.8 %
# Validataion accuracy is: 60.2 %
# Validataion accuracy is: 59.32 %
# Validataion accuracy is: 59.32 %
# Validataion accuracy is: 58.46 %
# Validataion accuracy is: 60.06 %
# Validataion accuracy is: 59.72 %
# Validataion accuracy is: 62.8 %
# Validataion accuracy is: 60.88 %
# Validataion accuracy is: 61.88 %
# Validataion accuracy is: 63.14 %
# Validataion accuracy is: 63.16 %
# Validataion accuracy is: 62.2 %
# Validataion accuracy is: 64.0 %
# Validataion accuracy is: 62.94 %
# Testing Accuracy of the network on the 10000 test images: 61.24 %

# %%
graph_acc_loss(train_acc1, val_acc1, train_loss1, val_loss1, glob)

# %%
graph_acc_loss(train_acc2, val_acc2, train_loss2, val_loss2, glob)

# %%
def graph2(temp,regtype):
    if regtype=='l2':
        reg = [5e-1, 5e-2, 5e-3, 5e-4]
    else:
        reg = [5e-3, 5e-4]
    
    fig, axis = plt.subplots(2,2)
    fig.set_size_inches(16,8)
    for i in range(len(temp)):
        axis[0][0].plot(temp[i][0],label='{}={}'.format(regtype,reg[i]))
        axis[0][1].plot(temp[i][1],label='{}={}'.format(regtype,reg[i]))
        axis[1][0].plot(temp[i][2],label='{}={}'.format(regtype,reg[i]))
        axis[1][1].plot(temp[i][3],label='{}={}'.format(regtype,reg[i]))
        plt.legend()

    axis[0][0].set_title('Training Accuracy')
    axis[0][1].set_title('Training Loss')
    axis[1][0].set_title('Validation Accuracy')
    axis[1][1].set_title('Validation Loss')

    plt.show()
    
    print("Test accuracy:")
    for i in range(len(reg)):
        print("\n {}={} \t|{}%".format(regtype,reg[i],temp[i][4]))

# %%
##### TESTING THE EFFECT OF DIFFERENT L2 REGULARISATION ON SGD #############
temp = run.run('3')  #using sgd with lr = 1e-1
# Out:
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.5
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 10.0 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.05
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 48.73 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 67.71 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.0005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 72.5 %

# %%
graph2(temp,'l2')
# Out:
# Test accuracy
#  	 l2=0.5 	|10.0%
#  	 l2=0.05 	|48.73%
#  	 l2=0.005 	|67.71%
#  	 l2=0.0005 	|72.5%

# %%
##### TESTING THE EFFECT OF DIFFERENT L2 REGULARISATION ON DFW #############
temp = run.run('4')  #using dfw with lr = 1e-1
# Out:
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.5
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 10.0 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.05
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 40.9 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.005
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 64.73 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.0005
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 71.86 %

# %%
graph2(temp,'l2')
# Out:
# Test accuracy
#  	 l2=0.5 	|10.0%
#  	 l2=0.05 	|40.9%
#  	 l2=0.005 	|64.73%
#  	 l2=0.0005 	|71.86%

# %%
##### TESTING THE EFFECT OF DIFFERENT L1 REGULARISATION ON SGD #############
temp = run.run('5')  #sgd
# Out:
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 10.0 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.0005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 62.29 %

# %%
graph2(temp,'l1')
# Out:
# Test accuracy:
#
#  l1=0.005 	|10.0%
#
#  l1=0.0005 	|62.29%

# %%
##### TESTING THE EFFECT OF DIFFERENT L1 REGULARISATION ON SGD #############
temp = run.run('6')  #dfw
# Out:
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.005
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 24.06 %
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.0005
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 56.71 %

# %%
graph2(temp,'l1')
# Out:
# Test accuracy:
#
#  l1=0.005 	|24.06%
#
#  l1=0.0005 	|56.71%

# %%
##### FINETUNE ON VGG #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = run.run('7')  #using sgd
# Out:
# Using data augmentation on CIFAR data set.
# Using pretrained VGG11, finetuning is assumed to be false
# Number of model parameters: 9278294
# Regularization param: 	 0.0005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 91.17 %

# %%
graph_acc_loss(train_acc1, val_acc1, train_loss1, val_loss1, glob)

# %%
##### FINETUNE ON VGG #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = run.run('8')  #using dfw
# Out:
# Using data augmentation on CIFAR data set.
# Using pretrained VGG11, finetuning is assumed to be false
# Number of model parameters: 9278294
# Regularization param: 	 0.0005
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 90.01 %

# %%
graph_acc_loss(train_acc1, val_acc1, train_loss1, val_loss1, glob)

# %%
##### FINETUNE ON VGG #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = run.run('11')  #using dfw
# Out:
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.0005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 72.61 %

# %%
##### FINETUNE ON VGG #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = run.run('11')  #using dfw
# Out:
# Using data augmentation on CIFAR data set.
# Model: cnn
# Number of model parameters: 60170
# Regularization param: 	 0.0005
# Loss function: MultiClassHingeLoss()
# Optimizer: 	 DFW
# Testing Accuracy of the network on the 10000 test images: 72.04 %

# %%
ROOTMNIST = r"E:\Suraj\University\Saarland\STUDIES\3d sem subjects\z_opt_ml\coderepo\datasets\mnist"
runmnist = whichRun(glob,l_vals,device,
               root=ROOTMNIST)

# %%
##### BEST MODEL,MNIST #############
train_acc1, train_loss1, val_acc1, val_loss1, test_acc1 = runmnist.run('9')  #using sgd
# Out:
# E:\Suraj\University\Saarland\STUDIES\3d sem subjects\z_opt_ml\coderepo\datasets\mnist
# Loading model trained on CIFAR10, to use on MNIST
# loading best_dfw
# model to be finetuned on MNIST
# Regularization param: 	 0.0005
# Loss function: CrossEntropyLoss()
# Optimizer: 	 SGD
# Testing Accuracy of the network on the 10000 test images: 98.92 %
# ([96.264,
#   97.98,
#   98.222,
#   98.444,
#   98.502,
#   98.638,
#   98.664,
#   98.752,
#   98.81,
#   98.846,
#   98.878,
#   98.888,
#   98.892,
#   98.958,
#   98.982,
#   98.904,
#   98.96,
#   99.008,
#   98.98,
#   99.058,
#   99.044,
#   99.048,
#   98.974,
#   99.012,
#   99.088,
#   99.014,
#   99.082,
#   99.112,
#   99.086,
#   99.11,
#   99.158,
#   99.054,
#   99.11,
#   99.092,
#   99.096,
#   99.108,
#   99.122,
#   99.086,
#   99.14,
#   99.178,
#   99.188,
#   99.14,
#   99.108,
#   99.206,
#   99.096,
#   99.146,
#   99.14,
#   99.132,
#   99.122,
#   99.166],
#  [0.0021320041161030532,
#   0.001112848944836296,
#   0.0009423215000052005,
#   0.0008343548251409083,
#   0.0008018122990150004,
#   0.0007566487770620734,
#   0.0007266903150081634,
#   0.0006834652627771721,
#   0.00067741932971403,
#   0.0006431540568592027,
#   0.0006328220606967807,
#   0.0006324457882996648,
#   0.0006075534017942846,
#   0.0005901683221664279,
#   0.0006024194281175733,
#   0.0005943269893177785,
#   0.0005841876172507182,
#   0.0005671064964914694,
#   0.0005823727445676923,
#   0.0005513705381471664,
#   0.0005614091902645305,
#   0.0005485706396773458,
#   0.0005614252409199252,
#   0.0005611945463670418,
#   0.0005285849906969815,
#   0.0005481503089144826,
#   0.000543513810141012,
#   0.000530183422556147,
#   0.0005265947889070958,
#   0.0005309431095467881,
#   0.0005282970883138478,
#   0.0005436917728139088,
#   0.000520368733163923,
#   0.0005361961908219382,
#   0.0005288699144218117,
#   0.0005268295643245802,
#   0.0005138239502254873,
#   0.0005282927834615111,
#   0.0005267223336920142,
#   0.0005154883303493262,
#   0.0005140573921753093,
#   0.0005075026547769084,
#   0.0005154342505289242,
#   0.0005080029220599681,
#   0.0005249737178953365,
#   0.0005127482638717629,
#   0.0005115508318506182,
#   0.0005182267797458917,
#   0.0005255604033754207,
#   0.0005104160916572436],
#  [98.11,
#   98.25,
#   98.31,
#   98.56,
#   98.57,
#   98.76,
#   98.69,
#   98.69,
#   98.78,
#   98.73,
#   98.69,
#   98.76,
#   98.81,
#   98.71,
#   98.71,
#   98.71,
#   98.9,
#   98.8,
#   98.74,
#   98.74,
#   98.8,
#   98.74,
#   98.74,
#   98.77,
#   98.78,
#   98.79,
#   98.8,
#   98.81,
#   98.87,
#   98.78,
#   98.88,
#   98.82,
#   98.82,
#   98.84,
#   98.76,
#   98.89,
#   98.82,
#   98.8,
#   98.79,
#   98.79,
#   98.78,
#   98.77,
#   98.91,
#   98.89,
#   98.83,
#   98.83,
#   98.85,
#   98.86,
#   98.84,
#   98.87],
#  [0.0009444282403448597,
#   0.0008299186027492396,
#   0.0007871131805586628,
#   0.0006787374016479589,
#   0.0006635584768489934,
#   0.0006325960774993291,
#   0.0006462326262611896,
#   0.00064936623419635,
#   0.0006145078368193935,
#   0.000604930823223549,
#   0.0006117686260811751,
#   0.0006189925955841318,
#   0.0005979711349937133,
#   0.0006217545234889258,
#   0.0006185913611232536,
#   0.0006072036248398945,
#   0.0005787051162100397,
#   0.000577896119109937,
#   0.000598212701571174,
#   0.0005893237039970699,
#   0.000584108699960052,
#   0.000592072540166555,
#   0.0005935561249265448,
#   0.0005964326197077753,
#   0.0005900738091761013,
#   0.0005952677971858065,
#   0.00059240666598198,
#   0.000593965282663703,
#   0.0005774358756578295,
#   0.0005797235147882021,
#   0.0005766407026647358,
#   0.0005849023202346871,
#   0.0005788927100627916,
#   0.0005833047455322231,
#   0.000576889258029405,
#   0.0005735921513551148,
#   0.0005742145665048156,
#   0.0005766644060175168,
#   0.0005980913242150564,
#   0.0005805842474481324,
#   0.0005823339912312804,
#   0.0005868182299716864,
#   0.0005674987563164905,
#   0.000570002113172086,
#   0.0005774228249589214,
#   0.0005795282961335033,
#   0.0005695222169480985,
#   0.0005716668001958169,
#   0.00057356077915465,
#   0.0005750968532898696],
#  98.92)

# %%
graph_acc_loss(train_acc2, val_acc2, train_loss2, val_loss2, glob)
